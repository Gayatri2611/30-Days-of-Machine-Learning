# %%
# 🐼 Day 5 - Pandas Basics

import pandas as pd

# 1️⃣ Create a DataFrame

data = {
    "Name": ["Amit", "Priya", "Rahul", "Sneha", "Rohan"],
    "Age": [22, 25, 21, 24, 23],
    "Department": ["IT", "HR", "Finance", "IT", "Marketing"],
    "Salary": [30000, 45000, 35000, 40000, 38000]
}

df = pd.DataFrame(data)

print("📊 DATAFRAME")
print(df)


# 2️⃣ First and Last Rows

print("\n🔹 FIRST 3 ROWS")
print(df.head(3))

print("\n🔹 LAST 2 ROWS")
print(df.tail(2))


# 3️⃣ Dataset Information

print("\n🔹 DATASET INFORMATION")
df.info()


# 4️⃣ Statistical Summary

print("\n🔹 STATISTICAL SUMMARY")
print(df.describe())


# 5️⃣ Selecting Columns

print("\n🔹 NAME AND SALARY")
print(df[["Name", "Salary"]])


# 6️⃣ Filtering Data

print("\n🔹 EMPLOYEES WITH SALARY ABOVE 35000")
print(df[df["Salary"] > 35000])
# Out:
# 📊 DATAFRAME
#     Name  Age Department  Salary
# 0   Amit   22         IT   30000
# 1  Priya   25         HR   45000
# 2  Rahul   21    Finance   35000
# 3  Sneha   24         IT   40000
# 4  Rohan   23  Marketing   38000
#
# 🔹 FIRST 3 ROWS
#     Name  Age Department  Salary
# 0   Amit   22         IT   30000
# 1  Priya   25         HR   45000
# 2  Rahul   21    Finance   35000
#
# 🔹 LAST 2 ROWS
#     Name  Age Department  Salary
# 3  Sneha   24         IT   40000
# 4  Rohan   23  Marketing   38000
#
# 🔹 DATASET INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Age         5 non-null      int64
#  2   Department  5 non-null      object
#  3   Salary      5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
#
# 🔹 STATISTICAL SUMMARY
# ...
