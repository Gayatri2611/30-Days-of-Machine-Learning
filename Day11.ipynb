# %%
# ⚙️ Day 11 - Data Preprocessing

import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Create dataset
data = {
    "Age": [22, 25, 28, 30, 35],
    "Salary": [30000, 45000, 50000, 60000, 75000],
    "Department": ["IT", "HR", "Finance", "IT", "HR"]
}

df = pd.DataFrame(data)

print("📊 ORIGINAL DATA")
print(df)


# 1️⃣ Encoding Categorical Data

encoder = LabelEncoder()

df["Department"] = encoder.fit_transform(df["Department"])

print("\n🔤 AFTER ENCODING")
print(df)


# 2️⃣ Feature Scaling
scaler = StandardScaler()

df[["Age", "Salary"]] = scaler.fit_transform(
    df[["Age", "Salary"]]
)
print("\n📏 AFTER FEATURE SCALING")
print(df)
# Out:
# 📊 ORIGINAL DATA
#    Age  Salary Department
# 0   22   30000         IT
# 1   25   45000         HR
# 2   28   50000    Finance
# 3   30   60000         IT
# 4   35   75000         HR
#
# 🔤 AFTER ENCODING
#    Age  Salary  Department
# 0   22   30000           2
# 1   25   45000           1
# 2   28   50000           0
# 3   30   60000           2
# 4   35   75000           1
#
# 📏 AFTER FEATURE SCALING
#         Age    Salary  Department
# 0 -1.355262 -1.463418           2
# 1 -0.677631 -0.465633           1
# 2  0.000000 -0.133038           0
# 3  0.451754  0.532152           2
# 4  1.581139  1.529937           1
