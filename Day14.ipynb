# %%
# 📈 Day 14 - Linear Regression

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# Create dataset
data = {
    "Study_Hours": [1, 2, 3, 4, 5, 6, 7, 8],
    "Score": [35, 40, 48, 55, 62, 70, 78, 85]
}

df = pd.DataFrame(data)

print("📊 DATASET")
print(df)

# Features and target
X = df[["Study_Hours"]]
y = df["Score"]

# Create and train model
model = LinearRegression()
model.fit(X, y)

# Predict scores
predictions = model.predict(X)

print("\n🎯 PREDICTIONS")
for hours, actual, predicted in zip(
    df["Study_Hours"], y, predictions
):
    print(
        f"{hours} hours → Actual: {actual}, "
        f"Predicted: {predicted:.2f}"
    )

# Predict for a new student
new_student = [[9]]
new_prediction = model.predict(new_student)

print("\n👨‍🎓 NEW STUDENT")
print("Study Hours:", new_student[0][0])
print("Predicted Score:", round(new_prediction[0], 2))

# Model equation
print("\n📐 MODEL EQUATION")
print("Slope:", round(model.coef_[0], 2))
print("Intercept:", round(model.intercept_, 2))

# Evaluation
mae = mean_absolute_error(y, predictions)
r2 = r2_score(y, predictions)

print("\n📊 MODEL EVALUATION")
print("Mean Absolute Error:", round(mae, 2))
print("R² Score:", round(r2, 2))

# Visualization
plt.figure(figsize=(7, 4))
plt.scatter(X, y, label="Actual Data")
plt.plot(X, predictions, label="Regression Line")
plt.xlabel("Study Hours")
plt.ylabel("Score")
plt.title("Study Hours vs Score")
plt.legend()
plt.show()
# Out:
# 📊 DATASET
#    Study_Hours  Score
# 0            1     35
# 1            2     40
# 2            3     48
# 3            4     55
# 4            5     62
# 5            6     70
# 6            7     78
# 7            8     85
#
# 🎯 PREDICTIONS
# 1 hours → Actual: 35, Predicted: 33.58
# 2 hours → Actual: 40, Predicted: 40.88
# 3 hours → Actual: 48, Predicted: 48.18
# 4 hours → Actual: 55, Predicted: 55.48
# 5 hours → Actual: 62, Predicted: 62.77
# 6 hours → Actual: 70, Predicted: 70.07
# 7 hours → Actual: 78, Predicted: 77.37
# 8 hours → Actual: 85, Predicted: 84.67
#
# 👨‍🎓 NEW STUDENT
# Study Hours: 9
# Predicted Score: 91.96
#
# 📐 MODEL EQUATION
# Slope: 7.3
# Intercept: 26.29
#
# 📊 MODEL EVALUATION
# Mean Absolute Error: 0.6
# R² Score: 1.0
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
